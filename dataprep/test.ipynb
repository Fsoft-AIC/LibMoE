# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
image_path = '/cm/archive/anonymous/data/image_onevision/identity_99684.jpg'
image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.title('identity_99622.jpg')
plt.show()

# %%
import json

# %%
with open("/cm/archive/anonymous/data/jsons/llava_v1_5_mix665k.json", "r") as f:
    data = json.load(f)

# %%
data[0]
# Out:
# {'id': '000000033471',
#  'image': 'coco/train2017/000000033471.jpg',
#  'conversations': [{'from': 'human',
#    'value': '\nWhat are the colors of the bus in the image?'},
#   {'from': 'gpt', 'value': 'The bus in the image is white and red.'},
#   {'from': 'human',
#    'value': 'What feature can be seen on the back of the bus?'},
#   {'from': 'gpt', 'value': 'The back of the bus features an advertisement.'},
#   {'from': 'human',
#    'value': 'Is the bus driving down the street or pulled off to the side?'},
#   {'from': 'gpt',
#    'value': 'The bus is driving down the street, which is crowded with people and other vehicles.'}]}

# %%
paths  = []
for sample in data:
    if "image" in sample:
        paths.append(sample['image'].split("/")[0])

# %%
import numpy as np

# %%
np.unique(paths)
# Out:
# array(['coco', 'gqa', 'ocr_vqa', 'textvqa', 'vg'], dtype='<U7')
